# %%
#Import Dependencies
import pandas as pd

# %%
path = "jupyter_notebookresources/vgsales.csv"
vg_sales_df = pd.read_csv(path)
vg_sales_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9e95c6c1a44c> in <module>
#       1 path = "resources/vgsales.csv"
# ----> 2 vg_sales_df = pd.read_csv(path)
#       3 vg_sales_df.head()
#
# ...
